# %%
import requests

# URL of the image
image_url = "https://facebook-ad-previews.nexxxt.cloud/865415801703393.jpg"

# Name for the downloaded image
file_name = "865415801703393.jpg"

# Send an HTTP GET request to the URL
response = requests.get(image_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Open the file in binary write mode and write the image content to it
    with open(file_name, 'wb') as f:
        f.write(response.content)
    print(f"Image downloaded as {file_name}")
else:
    print(f"Failed to download the image. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# c:\Users\jiri.pillar\Developer\python\meta_ads_crawler\meta_creative_image_scraper.ipynb Cell 1 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/jiri.pillar/Developer/python/meta_ads_crawler/meta_creative_image_scraper.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> base64_image = "[..."
#       <a href='vscode-notebook-cell:/c%3A/Users/jiri.pillar/Developer/python/meta_ads_crawler/meta_creative_image_scraper.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> # Decode the Base64 string to binary data
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jiri.pillar/Developer/python/meta_ads_crawler/meta_creative_image_scraper.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> binary_image = base64.b64decode(base64_image)
# ...
